# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# C:\Users\Manasa\AppData\Local\Temp\ipykernel_18692\265554930.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
dataset= pd.read_csv("anime-filtered.csv")

# %%
dataset.describe()
# Out:
#            anime_id         Score        Ranked    Popularity       Members  \
# count  14952.000000  14952.000000  13231.000000  14952.000000  1.495200e+04
# mean   19017.432718      6.511526   6829.853828   7465.970907  4.068648e+04
# std    14588.758618      0.807185   4168.929475   4313.169381  1.348744e+05
# min        1.000000      1.850000      1.000000      1.000000  2.000000e+02
# 25%     4602.500000      6.080000   3309.500000   3732.000000  7.360000e+02
# 50%    16729.000000      6.510000   6618.000000   7466.500000  3.493500e+03
# 75%    33513.250000      7.010000   9942.000000  11194.000000  1.919325e+04
# max    48492.000000      9.190000  15780.000000  17565.000000  2.589552e+06
#
#            Favorites       Watching     Completed        On-Hold  \
# count   14952.000000   14952.000000  1.495200e+04   14952.000000
# mean      537.629882    2619.806715  2.594310e+04    1121.307986
# std      4399.016449   15190.098642  9.812729e+04    4613.759597
# min         0.000000       0.000000  0.000000e+00       0.000000
# 25%         1.000000      27.000000  2.460000e+02      14.000000
# 50%         6.000000     127.000000  1.515500e+03      78.000000
# 75%        47.000000     723.000000  9.797000e+03     388.250000
# max    183914.000000  887333.000000  2.182587e+06  187919.000000
#
#              Dropped
# count   14952.000000
# mean     1377.861891
# std      5110.874501
# min         0.000000
# 25%        48.000000
# 50%       102.000000
# 75%       377.000000
# max    174710.000000

# %%
dataset.isnull()
# Out:
#        anime_id   Name  Score  Genres  English name  Japanese name  sypnopsis  \
# 0         False  False  False   False         False          False      False
# 1         False  False  False   False         False          False      False
# 2         False  False  False   False         False          False      False
# 3         False  False  False   False         False          False      False
# 4         False  False  False   False         False          False      False
# ...         ...    ...    ...     ...           ...            ...        ...
# 14947     False  False  False   False         False          False      False
# 14948     False  False  False   False         False          False      False
# 14949     False  False  False   False         False          False      False
# 14950     False  False  False   False         False          False      False
# 14951     False  False  False   False         False          False      False
#
#         Type  Episodes  Aired  ...  Duration  Rating  Ranked  Popularity  \
# 0      False     False  False  ...     False   False   False       False
# 1      False     False  False  ...     False   False   False       False
# 2      False     False  False  ...     False   False   False       False
# 3      False     False  False  ...     False   False   False       False
# 4      False     False  False  ...     False   False   False       False
# ...      ...       ...    ...  ...       ...     ...     ...         ...
# 14947  False     False  False  ...     False   False    True       False
# 14948  False     False  False  ...     False   False    True       False
# 14949  False     False  False  ...     False   False    True       False
# 14950  False     False  False  ...     False   False    True       False
# 14951  False     False  False  ...     False   False    True       False
#
#        Members  Favorites  Watching  Completed  On-Hold  Dropped
# 0        False      False     False      False    False    False
# 1        False      False     False      False    False    False
# 2        False      False     False      False    False    False
# 3        False      False     False      False    False    False
# 4        False      False     False      False    False    False
# ...        ...        ...       ...        ...      ...      ...
# 14947    False      False     False      False    False    False
# 14948    False      False     False      False    False    False
# 14949    False      False     False      False    False    False
# 14950    False      False     False      False    False    False
# 14951    False      False     False      False    False    False
#
# [14952 rows x 25 columns]

# %%
(dataset.isnull().sum()/dataset.shape[0])*100
# Out:
# anime_id          0.000000
# Name              0.000000
# Score             0.000000
# Genres            0.000000
# English name      0.000000
# Japanese name     0.000000
# sypnopsis         9.028892
# Type              0.000000
# Episodes          0.000000
# Aired             0.000000
# Premiered         0.000000
# Producers         0.000000
# Licensors         0.000000
# Studios           0.000000
# Source            0.000000
# Duration          0.000000
# Rating            0.000000
# Ranked           11.510166
# Popularity        0.000000
# Members           0.000000
# Favorites         0.000000
# Watching          0.000000
# Completed         0.000000
# On-Hold           0.000000
# Dropped           0.000000
# dtype: float64

# %%
dataset.isnull().sum().sum()
# Out:
# 3071

# %%
sns.heatmap(dataset.isnull())
plt.show()

# %%
dataset.shape
# Out:
# (14952, 25)

# %%
dataset.shape
# Out:
# (13602, 24)

# %%
((14952-13602)/14952)*100
# Out:
# 9.028892455858747

# %%
(dataset.isnull().sum()/dataset.shape[0])*100
# Out:
# anime_id         0.000000
# Name             0.000000
# Score            0.000000
# Genres           0.000000
# English name     0.000000
# Japanese name    0.000000
# sypnopsis        9.028892
# Type             0.000000
# Episodes         0.000000
# Aired            0.000000
# Premiered        0.000000
# Producers        0.000000
# Licensors        0.000000
# Studios          0.000000
# Source           0.000000
# Duration         0.000000
# Rating           0.000000
# Popularity       0.000000
# Members          0.000000
# Favorites        0.000000
# Watching         0.000000
# Completed        0.000000
# On-Hold          0.000000
# Dropped          0.000000
# dtype: float64

# %%
dataset.drop(columns=["Ranked"], inplace=True)

# %%
dataset.dropna(inplace=True)

# %%
import numpy as np

# %%
a = np.eye(4,3)
print(a)
# Out:
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]
#  [0. 0. 0.]]

# %%
#ls= -,-.,--,:   marker=o,*,,,.,p,P,d,D
x=np.array([12,43,56,78,69])
y=np.array([2,4,6,8,10])
plt.bar(x,y)
plt.grid(axis='y')

# %%
import numpy as np
import matplotlib.pyplot as plt
